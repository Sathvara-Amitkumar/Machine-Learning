# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Global Weapons Systems.csv')

# %%
df.head()
# Out:
#    ID        Weapon_Name Country_of_Origin     Manufacturer   Category  \
# 0   1       M4A1 Carbine               USA  Colt/FN Herstal  Small Arm
# 1   2              M16A4               USA       FN Herstal  Small Arm
# 2   3  XM5 SIG MCX Spear               USA        SIG Sauer  Small Arm
# 3   4           M249 SAW               USA       FN Herstal  Small Arm
# 4   5              M240B               USA       FN Herstal  Small Arm
#
#                    Subcategory  Year_Introduced  Year_Retired Service_Status  \
# 0                Assault Rifle             1994           NaN         Active
# 1                Assault Rifle             1985           NaN         Active
# 2                Assault Rifle             2022           NaN         Active
# 3            Light Machine Gun             1984           NaN         Active
# 4  General Purpose Machine Gun             1977           NaN         Active
#
#           Caliber  ... Generation  Theater_of_Operation    Export_Status  \
# ...

# %%
df.shape
# Out:
# (10000, 36)

# %%
df.describe()
# Out:
#                 ID  Year_Introduced  Year_Retired  Effective_Range_m  \
# count  10000.00000     10000.000000    740.000000       8.614000e+03
# mean    5000.50000      1984.446700   2007.240541       2.115455e+06
# std     2886.89568        23.145374     16.209771       3.763725e+06
# min        1.00000      1933.000000   1956.000000       2.000000e+01
# 25%     2500.75000      1964.000000   1999.000000       6.026000e+03
# 50%     5000.50000      1985.000000   2012.000000       1.654500e+05
# 75%     7500.25000      2004.000000   2021.000000       2.153092e+06
# max    10000.00000      2024.000000   2025.000000       1.499962e+07
#
#         Max_Range_m     Weight_kg      Length_mm  Barrel_Length_mm  \
# count  8.647000e+03  9.593000e+03    7473.000000       1628.000000
# mean   3.464961e+06  5.326652e+06   26371.799813        704.988329
# std    6.201005e+06  1.948103e+07   60585.248989        385.027879
# min    7.600000e+01  6.200000e-01     150.000000        100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     10000 non-null  int64
#  1   Weapon_Name            10000 non-null  object
#  2   Country_of_Origin      10000 non-null  object
#  3   Manufacturer           10000 non-null  object
#  4   Category               10000 non-null  object
#  5   Subcategory            10000 non-null  object
#  6   Year_Introduced        10000 non-null  int64
#  7   Year_Retired           740 non-null    float64
#  8   Service_Status         10000 non-null  object
#  9   Caliber                9803 non-null   object
#  10  Action_Type            10000 non-null  object
#  11  Effective_Range_m      8614 non-null   float64
#  12  Max_Range_m            8647 non-null   float64
#  13  Weight_kg              9593 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# ID                          0
# Weapon_Name                 0
# Country_of_Origin           0
# Manufacturer                0
# Category                    0
# Subcategory                 0
# Year_Introduced             0
# Year_Retired             9260
# Service_Status              0
# Caliber                   197
# Action_Type                 0
# Effective_Range_m        1386
# Max_Range_m              1353
# Weight_kg                 407
# Length_mm                2527
# Barrel_Length_mm         8372
# Muzzle_Velocity_mps      8352
# Rate_of_Fire_rpm         7589
# Magazine_Capacity        5205
# Warhead_Weight_kg        5449
# Max_Speed_kmh            7563
# Crew_Size                   0
# Unit_Cost_USD               2
# Num_Operator_Nations        0
# Primary_Users               0
# NATO_Compatible          2457
# Generation                  0
# Theater_of_Operation        0
# Export_Status               0
# Combat_Proven               0
# Propulsion_Type          1104
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Weapon_Name', 'Country_of_Origin', 'Manufacturer', 'Category',
#        'Subcategory', 'Year_Introduced', 'Year_Retired', 'Service_Status',
#        'Caliber', 'Action_Type', 'Effective_Range_m', 'Max_Range_m',
#        'Weight_kg', 'Length_mm', 'Barrel_Length_mm', 'Muzzle_Velocity_mps',
#        'Rate_of_Fire_rpm', 'Magazine_Capacity', 'Warhead_Weight_kg',
#        'Max_Speed_kmh', 'Crew_Size', 'Unit_Cost_USD', 'Num_Operator_Nations',
#        'Primary_Users', 'NATO_Compatible', 'Generation',
#        'Theater_of_Operation', 'Export_Status', 'Combat_Proven',
#        'Propulsion_Type', 'Guidance_System', 'Communication_System',
#        'Operating_Environment', 'Protection_Level', 'Notes'],
#       dtype='object')

# %%
sns.countplot(df['Year_Retired'])
# Out:
# <Axes: ylabel='count'>
